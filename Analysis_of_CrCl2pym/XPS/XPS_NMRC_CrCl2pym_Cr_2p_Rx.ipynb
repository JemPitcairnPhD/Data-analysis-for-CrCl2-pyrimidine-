# %%
# %matplotlib notebook

# %%
import sys
import matplotlib.pyplot as plt
import numpy as np

# %%
datafile = "XPS_NMRC_CrCl2pym_Cr_2p_1"
data = np.genfromtxt(datafile,skip_header=7)
data = data[np.argsort(data[:, 0])] # sort all data by binding energy
BE = data[:,0]

fig = plt.figure(1, figsize=(3.6, 3.6))
ax1 = plt.subplot()

ax1.plot (BE,data[:,1]/1000, 'o', mfc='none', color='teal', label='data')
ax1.plot (BE,data[:,9]/1000, color='teal', label='fit')
ax1.plot (BE,data[:,2]/1000, color='red', label='Cr$^\mathrm{III}$')
ax1.plot (BE,data[:,3]/1000, color='red')
ax1.plot (BE,data[:,4]/1000, color='blue', label='Cr$^\mathrm{VI}$')
ax1.plot (BE,data[:,5]/1000, color='blue')
ax1.plot (BE,data[:,6]/1000, color='green', label='Cr$^0$')
ax1.plot (BE,data[:,7]/1000, color='green')
ax1.plot (BE,data[:,8]/1000, color='teal') #, label='background')


ax1.set_xlabel('Binding Energy (eV)',fontsize=9)
ax1.set_ylabel('CPS',fontsize=9)
ax1.set_xlim((595,566))
ax1.text(595, 3.38, '$\\times 10^3$',fontsize=7)
#ax1.set_ylim((0.5,1))
ax1.tick_params(axis='both', labelsize=8)
plt.legend(frameon=False, loc='upper right', fontsize=7)
#plt.savefig('200124_sijisi_XPS_CrpymCl2_Cr_2p_1.pdf', bbox_inches='tight', transparent=True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="360">

# %%
#datafile must be exported from CasaXPS by "Save Tab ASCII" > rows of tables
datafile = "XPS_NMRC_CrCl2pym_Cr_2p_2"
data = np.genfromtxt(datafile,skip_header=7)
data = data[np.argsort(data[:, 0])] # sort all data by binding energy
BE = data[:,0]

fig = plt.figure(2, figsize=(3.6, 3.6))
ax1 = plt.subplot()

ax1.plot (BE,data[:,1]/1000, 'o', mfc='none', color='teal', label='data')
ax1.plot (BE,data[:,7]/1000, color='teal', label='fit')
ax1.plot (BE,data[:,2]/1000, color='red', label='Cr$^\mathrm{III}$')
ax1.plot (BE,data[:,3]/1000, color='red')
ax1.plot (BE,data[:,4]/1000, color='green', label='Cr$^0$')
ax1.plot (BE,data[:,5]/1000, color='green')
ax1.plot (BE,data[:,6]/1000, color='teal') #, label='background')

ax1.set_xlabel('Binding Energy (eV)',fontsize=9)
ax1.set_ylabel('CPS',fontsize=9)
ax1.set_xlim((595,566))
ax1.text(595, 4.2, '$\\times 10^3$',fontsize=7)
#ax1.set_ylim((0.5,1))
ax1.tick_params(axis='both', labelsize=8)
plt.legend(frameon=False, loc='upper right', fontsize=7)
#plt.savefig('200124_sijisi_XPS_CrpymCl2_Cr_2p_2.pdf', bbox_inches='tight', transparent=True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="360">

# %%
#datafile must be exported from CasaXPS by "Save Tab ASCII" > rows of tables
datafile = "XPS_NMRC_CrCl2pym_Cr_2p_3"
data = np.genfromtxt(datafile,skip_header=7)
data = data[np.argsort(data[:, 0])] # sort all data by binding energy
BE = data[:,0]

fig = plt.figure(3, figsize=(3.6, 3.6))
ax1 = plt.subplot()

ax1.plot (BE,data[:,1], 'o', mfc='none', color='teal', label='data')

ax1.plot (BE,data[:,7], color='teal', label='fit')

ax1.plot (BE,data[:,2], color='red', label='Cr$^\mathrm{III}$')
ax1.plot (BE,data[:,3], color='red')

ax1.plot (BE,data[:,4], color='green', label='Cr$^0$')
ax1.plot (BE,data[:,5], color='green')

ax1.plot (BE,data[:,6], color='teal')

ax1.set_xlabel('Binding Energy (eV)',fontsize=9)
ax1.set_ylabel('CPS',fontsize=9)
ax1.set_xlim((595,566))
#ax1.set_ylim((0.5,1))
ax1.tick_params(axis='both', labelsize=8)
plt.legend(frameon=False, loc='upper right', fontsize=7)
#plt.savefig('200124_sijisi_XPS_CrpymCl2_Cr_2p_3.pdf', bbox_inches='tight', transparent=True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="360">

# %%
#datafile must be exported from CasaXPS by "Save Tab ASCII" > rows of tables
datafile = "XPS_NMRC_CrCl2pym_Cr_2p_4"
data = np.genfromtxt(datafile,skip_header=7)
data = data[np.argsort(data[:, 0])] # sort all data by binding energy
BE = data[:,0]

fig = plt.figure(4, figsize=(3.6, 3.6))
ax1 = plt.subplot()

ax1.plot (BE,data[:,1], 'o', mfc='none', color='teal', label='data')

ax1.plot (BE,data[:,9], color='teal', label='fit')

ax1.plot (BE,data[:,2], color='blue', label='Cr$^\mathrm{VI}$')
ax1.plot (BE,data[:,3], color='blue')

ax1.plot (BE,data[:,4], color='red', label='Cr$^\mathrm{III}$')
ax1.plot (BE,data[:,5], color='red')

ax1.plot (BE,data[:,6], color='green', label='Cr$^0$')
ax1.plot (BE,data[:,7], color='green')

ax1.plot (BE,data[:,8], color='teal')

ax1.set_xlabel('Binding Energy (eV)',fontsize=9)
ax1.set_ylabel('CPS',fontsize=9)
ax1.set_xlim((595,566))
#ax1.set_ylim((0.5,1))
ax1.tick_params(axis='both', labelsize=8)
plt.legend(frameon=False, loc='upper right', fontsize=7)
#plt.savefig('200124_sijisi_XPS_CrpymCl2_Cr_2p_4.pdf', bbox_inches='tight', transparent=True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="360">

# %%
#datafile must be exported from CasaXPS by "Save Tab ASCII" > rows of tables
datafile = "XPS_NMRC_CrCl2pym_Cr_2p_5"
data = np.genfromtxt(datafile,skip_header=7)
data = data[np.argsort(data[:, 0])] # sort all data by binding energy
BE = data[:,0]

fig = plt.figure(5, figsize=(3.6, 3.6))
ax1 = plt.subplot()

ax1.plot (BE,data[:,1], 'o', mfc='none', color='teal', label='data')

ax1.plot (BE,data[:,7], color='teal', label='fit')

ax1.plot (BE,data[:,2], color='red', label='Cr$^\mathrm{III}$')
ax1.plot (BE,data[:,3], color='red')

ax1.plot (BE,data[:,4], color='green', label='Cr$^0$')
ax1.plot (BE,data[:,5], color='green')

ax1.plot (BE,data[:,6], color='teal')

ax1.set_xlabel('Binding Energy (eV)',fontsize=9)
ax1.set_ylabel('CPS',fontsize=9)
ax1.set_xlim((595,566))
#ax1.set_ylim((0.5,1))
ax1.tick_params(axis='both', labelsize=8)
plt.legend(frameon=False, loc='upper right', fontsize=7)
#plt.savefig('200124_sijisi_XPS_CrpymCl2_Cr_2p_5.pdf', bbox_inches='tight', transparent=True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="360">

# %%
#datafile must be exported from CasaXPS by "Save Tab ASCII" > rows of tables
datafile = "XPS_NMRC_CrCl2pym_Cr_2p_6"
data = np.genfromtxt(datafile,skip_header=7)
data = data[np.argsort(data[:, 0])] # sort all data by binding energy
BE = data[:,0]

fig = plt.figure(7, figsize=(3.6,3.6))
ax1 = plt.subplot()

ax1.plot (BE,data[:,1], 'o', mfc='none', color='teal', label='data')

ax1.plot (BE,data[:,7], color='teal', label='fit')

ax1.plot (BE,data[:,4], color='red', label='Cr$^\mathrm{III}$')
ax1.plot (BE,data[:,5], color='red')

ax1.plot (BE,data[:,2], color='green', label='Cr$^0$')
ax1.plot (BE,data[:,3], color='green')

ax1.plot (BE,data[:,6], color='teal')

ax1.set_xlabel('Binding Energy (eV)',fontsize=9)
ax1.set_ylabel('CPS',fontsize=9)
ax1.set_xlim((595,566))
#ax1.set_ylim((0.5,1))
ax1.tick_params(axis='both', labelsize=8)
plt.legend(frameon=False, loc='upper right', fontsize=7)
#plt.savefig('200124_sijisi_XPS_CrpymCl2_Cr_2p_6.pdf', bbox_inches='tight', transparent=True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="360">
